# %%
import geopandas as gpd; gdf = gpd.read_file("/Users/noahkim/Library/Mobile Documents/com~apple~CloudDocs/Documents/Documents - Noah's MacBook Air/UTPS/Traffic_Sim/utps-ts-repo/data/raw/road_network_v4_clipped_single.gpkg"); print("CRS:", gdf.crs); print("Bounds:", gdf.total_bounds); print("Sample coords:", list(gdf.geometry.iloc[0].coords)[:2])
# Out:
# CRS: EPSG:32632
# Bounds: [1236498.62928664 4887520.24673499 1264933.91604909 4906506.99336281]
# Sample coords: [(1247018.6685751462, 4904564.165264409), (1247020.44, 4904562.76)]
